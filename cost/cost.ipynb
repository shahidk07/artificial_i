# %%
# Optional  Lab: Cost Function 


## Tools
import numpy as np
# %matplotlib widget
import matplotlib.pyplot as plt
 ## from lab_utils_uni import plt_intuition, plt_stationary, plt_update_onclick, soup_bowl
##plt.style.use('./deeplearning.mplstyle')

## Problem Statement


x_train = np.array([1.0, 2.0])           #(size in 1000 square feet)
y_train = np.array([300.0, 500.0])           #(price in 1000s of dollars)

## Computing Cost

def compute_cost(x, y, w, b): 
    """
    Computes the cost function for linear regression.
    
    Args:
      x (ndarray (m,)): Data, m examples 
      y (ndarray (m,)): target values
      w,b (scalar)    : model parameters  
    
    Returns
        total_cost (float): The cost of using w,b as the parameters for linear regression
               to fit the data points in x and y
    """
  
    m = x.shape[0] 
    
    cost_sum = 0 
    for i in range(m): 
        f_wb = w * x[i] + b   
        cost = (f_wb - y[i]) ** 2  
        cost_sum = cost_sum + cost  
    total_cost = (1 / (2 * m)) * cost_sum  

    return total_cost


#plt_intuition(x_train,y_train)



x_train = np.array([1.0, 1.7, 2.0, 2.5, 3.0, 3.2])
y_train = np.array([250, 300, 480,  430,   630, 730,])

# %%
# %pip install ipympl
# Out:
# Collecting ipympl
#   Using cached ipympl-0.9.8-py3-none-any.whl.metadata (8.9 kB)
# Requirement already satisfied: ipython<10 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from ipympl) (9.9.0)
# Collecting ipywidgets<9,>=7.6.0 (from ipympl)
#   Using cached ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Collecting matplotlib<4,>=3.5.0 (from ipympl)
#   Using cached matplotlib-3.10.8-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (52 kB)
# Collecting numpy (from ipympl)
#   Using cached numpy-2.4.1-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Collecting pillow (from ipympl)
#   Using cached pillow-12.1.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (8.8 kB)
# Requirement already satisfied: traitlets<6 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from ipympl) (5.14.3)
# Requirement already satisfied: decorator>=4.3.2 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from ipython<10->ipympl) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from ipython<10->ipympl) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from ipython<10->ipympl) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from ipython<10->ipympl) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from ipython<10->ipympl) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from ipython<10->ipympl) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from ipython<10->ipympl) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from ipython<10->ipympl) (0.6.3)
# Requirement already satisfied: comm>=0.1.3 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from ipywidgets<9,>=7.6.0->ipympl) (0.2.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets<9,>=7.6.0->ipympl)
#   Using cached widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets<9,>=7.6.0->ipympl)
#   Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Collecting contourpy>=1.0.1 (from matplotlib<4,>=3.5.0->ipympl)
#   Using cached contourpy-1.3.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib<4,>=3.5.0->ipympl)
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib<4,>=3.5.0->ipympl)
#   Using cached fonttools-4.61.1-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl.metadata (114 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib<4,>=3.5.0->ipympl)
#   Using cached kiwisolver-1.4.9-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (6.3 kB)
# Requirement already satisfied: packaging>=20.0 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from matplotlib<4,>=3.5.0->ipympl) (25.0)
# Collecting pyparsing>=3 (from matplotlib<4,>=3.5.0->ipympl)
#   Using cached pyparsing-3.3.1-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from matplotlib<4,>=3.5.0->ipympl) (2.9.0.post0)
# Requirement already satisfied: wcwidth in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython<10->ipympl) (0.2.14)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from jedi>=0.18.1->ipython<10->ipympl) (0.8.5)
# Requirement already satisfied: ptyprocess>=0.5 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from pexpect>4.3->ipython<10->ipympl) (0.7.0)
# Requirement already satisfied: six>=1.5 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from python-dateutil>=2.7->matplotlib<4,>=3.5.0->ipympl) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython<10->ipympl) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython<10->ipympl) (3.0.1)
# Requirement already satisfied: pure-eval in /home/shahidkx07/artificial_i/.venv/lib/python3.13/site-packages (from stack_data>=0.6.0->ipython<10->ipympl) (0.2.3)
# Using cached ipympl-0.9.8-py3-none-any.whl (515 kB)
# Using cached ipywidgets-8.1.8-py3-none-any.whl (139 kB)
# Using cached jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
# Using cached matplotlib-3.10.8-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (8.7 MB)
# Using cached widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
# Using cached contourpy-1.3.3-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (362 kB)
# Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Using cached fonttools-4.61.1-cp313-cp313-manylinux1_x86_64.manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_5_x86_64.whl (4.9 MB)
# Using cached kiwisolver-1.4.9-cp313-cp313-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (1.5 MB)
# Using cached numpy-2.4.1-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.4 MB)
# Using cached pillow-12.1.0-cp313-cp313-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (7.0 MB)
# Using cached pyparsing-3.3.1-py3-none-any.whl (121 kB)
# Installing collected packages: widgetsnbextension, pyparsing, pillow, numpy, kiwisolver, jupyterlab_widgets, fonttools, cycler, contourpy, matplotlib, ipywidgets, ipympl
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12/12 [ipympl]10/12 [ipywidgets]widgets]
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 ipympl-0.9.8 ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 kiwisolver-1.4.9 matplotlib-3.10.8 numpy-2.4.1 pillow-12.1.0 pyparsing-3.3.1 widgetsnbextension-4.0.15
# Note: you may need to restart the kernel to use updated packages.

# %%
import ipympl
print(ipympl.__version__)
# Out:
# 0.9.8

# %%
import sys
print(sys.executable)
# Out:
# /home/shahidkx07/artificial_i/venv/bin/python
